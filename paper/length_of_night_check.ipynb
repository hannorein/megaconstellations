# %%
import numpy as np
import sys
sys.path.insert(0,'../model')
import mega
import matplotlib.pyplot as plt
from matplotlib.collections import PatchCollection
cm = plt.cm.get_cmap('plasma_r')

# %%
times = np.linspace(0.,12.,1000)
lon = [mega.length_of_night(month=t,latitude=50.,p=17) for t in times]
plt.plot(times,lon)
plt.axhline(12)
